# %%
import json
import os
from glob import glob
from IPython.display import display
from PIL import Image, ImageOps

# %%
def process_crop(crop_img, annotation, annotation_file):
    display(crop_img)
    print("Processed bbox for annotation id:", annotation["id"], 'file:', annotation_file)

# %%
def load_json(path):
    with open(path, "r") as f:
        return json.load(f)


def iterate_crops(images_dir, annotations_dir):
    # Find all JSON files inside annotations_dir
    json_files = sorted(glob(os.path.join(annotations_dir, "*.json")))

    for annotation_file in json_files:
        data = load_json(annotation_file)

        # Map image_id → file_name for this annotation file
        id_to_filename = {img["id"]: img["file_name"] for img in data["images"]}

        for ann in data["annotations"]:
            image_id = ann["image_id"]
            bbox = ann["bbox"]  # [x, y, width, height]

            if image_id not in id_to_filename:
                print(f"Warning: image_id {image_id} not found in {annotation_file}")
                continue

            img_path = os.path.join(images_dir, id_to_filename[image_id])
            
            if not os.path.exists(img_path):
                print(f"Missing image file {img_path}")
                continue

            img = Image.open(img_path).convert("RGB")
            img = ImageOps.exif_transpose(img)

            x, y, w, h = bbox

            crop = img.crop((x, y, x + w, y + h))

            # Send crop to your analysis function
            process_crop(crop, ann, annotation_file)

# %%
iterate_crops("data/images", "data/annotations")
# Out:
# Processed bbox for annotation id: 1 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 2 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 3 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 4 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 5 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 6 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 7 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 8 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 9 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 10 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 11 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 12 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 13 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 14 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 15 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 16 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 17 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 18 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 19 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 20 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 21 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 22 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 23 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 24 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 25 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 26 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 27 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 28 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 29 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 30 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 31 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 32 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 33 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 34 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 35 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 36 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 37 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 38 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 39 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 40 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 41 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 42 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 43 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 44 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 45 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 46 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 47 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 48 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 49 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 50 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 51 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 52 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 53 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 54 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 55 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 56 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 57 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 58 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 59 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 60 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 61 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 62 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 63 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 64 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 65 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 66 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 67 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 68 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 69 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 70 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 71 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 72 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 73 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 74 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 75 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 76 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 77 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 78 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 79 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 80 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 81 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 82 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 83 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 84 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 85 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 86 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 87 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 88 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 89 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 90 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 91 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 92 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 93 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 94 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 95 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 96 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 97 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 98 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 99 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 100 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 101 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 102 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 103 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 104 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 105 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 106 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 107 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 108 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 109 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 110 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 111 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 112 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 113 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 114 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 115 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 116 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 117 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 118 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 119 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 120 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 121 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 122 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 123 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 124 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 125 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 126 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 127 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 128 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 129 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 130 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 131 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 132 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 133 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 134 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 135 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 136 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 137 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 138 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 139 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 140 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 141 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 142 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 143 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 144 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 145 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 146 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 147 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 148 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 149 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 150 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 151 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 152 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 153 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 154 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 155 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 156 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 157 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 158 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 159 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 160 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 161 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 162 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 163 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 164 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 165 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 166 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 167 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 168 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 169 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 170 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 171 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 172 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 173 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 174 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 175 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 176 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 177 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 178 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 179 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 180 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 181 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 182 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 183 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 184 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 185 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 186 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 187 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 188 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 189 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 190 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 191 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 192 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 193 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 194 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 195 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 196 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 197 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 198 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 199 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 200 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 201 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 202 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 203 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 204 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 205 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 206 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 207 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 208 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 209 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 210 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 211 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 212 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 213 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 214 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 215 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 216 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 217 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 218 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 219 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 220 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 221 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 222 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 223 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 224 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 225 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 226 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 227 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 228 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 229 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 230 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 231 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 232 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 233 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 234 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 235 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 236 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 237 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 238 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 239 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 240 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 241 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 242 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 243 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 244 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 245 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 246 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 247 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 248 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 249 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 250 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 251 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 252 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 253 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 254 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 255 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 256 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 257 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 258 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 259 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 260 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 261 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 262 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 263 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 264 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 265 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 266 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 267 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 268 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 269 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 270 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 271 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 272 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 273 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 274 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 275 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 276 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 277 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 278 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: 279 file: data/annotations/hold_annotations1.json
# Processed bbox for annotation id: